# %%
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=0'
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import Sequence
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from glob import glob
# Out:
# WARNING:tensorflow:From c:\Users\ioana\anaconda3\envs\tiny_radar\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Constants
RTM_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\RTM_images'
DTM_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\DTM_images'
ATM_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\ATM_images'
SOR_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\Signal_Energy_SOR'
SOT_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\Signal_Energy_SOT'

IMG_SIZE = (32, 32)
SEQ_LEN = 5

# %%
# === Utility: Loaders ===
def load_modality_file(path):
    if path.endswith(".npy"):
        try:
            arr = np.load(path)
            arr = np.resize(arr, IMG_SIZE)  # Resize to (32, 32)
            return arr[:, :, np.newaxis].astype(np.uint8)
        except Exception as e:
            print(f"[Error loading .npy] {path} → {e}")
            return np.zeros((*IMG_SIZE, 1), dtype=np.uint8)
    else:
        img = load_img(path, color_mode='grayscale', target_size=IMG_SIZE)
        return img_to_array(img).astype(np.uint8)

# === Index Dataset ===
def index_sequences(rtm_path, dtm_path, atm_path, sor_path, sot_path, seq_len=5, exclude=None):
    train, test, gestures = [], [], set()
    exclude = set(exclude or [])

    for person in sorted(os.listdir(rtm_path)):
        target = test if person in exclude else train
        for session in os.listdir(os.path.join(rtm_path, person)):
            for gesture in os.listdir(os.path.join(rtm_path, person, session)):
                rtm_files = sorted(glob(os.path.join(rtm_path, person, session, gesture, '*.png')))
                dtm_files = sorted(glob(os.path.join(dtm_path, person, session, gesture, '*.png')))
                atm_files = sorted(glob(os.path.join(atm_path, person, session, gesture, '*.png')))
                sor_files = sorted(glob(os.path.join(sor_path, person, session, gesture, '*.npy')))
                sot_files = sorted(glob(os.path.join(sot_path, person, session, gesture, '*.npy')))

                n = min(len(rtm_files), len(dtm_files), len(atm_files), len(sor_files), len(sot_files))
                gestures.add(gesture)
                for i in range(n - seq_len + 1):
                    target.append({
                        'rtm': rtm_files[i:i+seq_len],
                        'dtm': dtm_files[i:i+seq_len],
                        'atm': atm_files[i:i+seq_len],
                        'sor': sor_files[i:i+seq_len],
                        'sot': sot_files[i:i+seq_len],
                        'label': gesture
                    })

    label_map = {g: i for i, g in enumerate(sorted(gestures))}
    train_data, val_data = train_test_split(train, test_size=0.2, random_state=42)
    return train_data, val_data, test, label_map


# === Data Generator ===
class SingleInputSequence(Sequence):
    def __init__(self, samples, label_map, batch_size=64, seq_len=5, shuffle_data=False):
        self.samples = samples
        self.label_map = label_map
        self.batch_size = batch_size
        self.seq_len = seq_len
        self.shuffle_data = shuffle_data
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.samples) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle_data:
            self.samples = shuffle(self.samples)

    def __getitem__(self, idx):
        batch = self.samples[idx * self.batch_size: (idx + 1) * self.batch_size]
        X, y = [], []
        for sample in batch:
            rtm = [load_modality_file(p) for p in sample['rtm']]
            dtm = [load_modality_file(p) for p in sample['dtm']]
            atm = [load_modality_file(p) for p in sample['atm']]
            sor = [load_modality_file(p) for p in sample['sor']]
            sot = [load_modality_file(p) for p in sample['sot']]

            # Concatenate vertically along height (same width = 32)
            sequence = np.concatenate(rtm + dtm + atm + sor + sot, axis=0)  # shape: (5*5*32, 32, 1)
            X.append(sequence)
            y.append(self.label_map[sample['label']])
        X = np.array(X).astype(np.float32) / 255.0  # Normalize to [0, 1]
        return X, np.array(y)

# %%
def build_stm32_deployable_model(input_shape=(800, 32, 1), num_classes=13):
    inputs = tf.keras.Input(shape=input_shape, name="input")

    # === 1. Split Input ===
    rtm = layers.Cropping2D(((0, 640), (0, 0)))(inputs)       # 0:160
    dtm = layers.Cropping2D(((160, 480), (0, 0)))(inputs)     # 160:320
    atm = layers.Cropping2D(((320, 320), (0, 0)))(inputs)     # 320:480
    sor = layers.Cropping2D(((480, 160), (0, 0)))(inputs)     # 480:640
    sot = layers.Cropping2D(((640, 0), (0, 0)))(inputs)   

    def cnn_branch():
        inp = tf.keras.Input(shape=(160, 32, 1))
        x = layers.Conv2D(16, 3, activation='relu', padding='same')(inp)
        x = layers.DepthwiseConv2D(3, activation='relu', padding='same')(x)
        x = layers.MaxPooling2D(2)(x)  

        x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
        x = layers.MaxPooling2D(2)(x)  

        x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
        x = layers.GlobalAveragePooling2D()(x)
        return tf.keras.Model(inp, x)


    branch = cnn_branch()

    # === 2. Process each modality ===
    feat_rtm = branch(rtm)
    feat_dtm = branch(dtm)
    feat_atm = branch(atm)
    feat_sor = branch(sor)
    feat_sot = branch(sot)

    # === 3. Simulated temporal fusion ===
    x = layers.Concatenate()([feat_rtm, feat_dtm, feat_atm, feat_sor, feat_sot])  # (64 * 5 = 320)
    x = layers.Reshape((5, 64))(x)  # (5 time steps, 64 features)

    x = layers.Conv1D(64, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.Flatten()(x)

    # === 4. MLP Head ===
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return tf.keras.Model(inputs, outputs)

# %%
# Updated exclusion list
excluded = {f'p0_{i}' for i in range(15, 21)}  # Exclude p0_15 to p0_20

# Update dataset indexing with SOR and SOT
train_samples, val_samples, test_samples, label_map = index_sequences(
    RTM_PATH, DTM_PATH, ATM_PATH, SOR_PATH, SOT_PATH, seq_len=SEQ_LEN, exclude=excluded
)

# Updated data generator instantiation for 5-modality input
train_gen = SingleInputSequence(train_samples, label_map, batch_size=128, shuffle_data=True)
val_gen = SingleInputSequence(val_samples, label_map, batch_size=128, shuffle_data=False)

# %%
model = build_stm32_deployable_model(input_shape=(800, 32, 1), num_classes=13)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 800, 32, 1)]         0         []
#
#  cropping2d_21 (Cropping2D)  (None, 160, 32, 1)           0         ['input[0][0]']
#
#  cropping2d_22 (Cropping2D)  (None, 160, 32, 1)           0         ['input[0][0]']
#
#  cropping2d_23 (Cropping2D)  (None, 160, 32, 1)           0         ['input[0][0]']
#
#  cropping2d_24 (Cropping2D)  (None, 160, 32, 1)           0         ['input[0][0]']
#
#  cropping2d_25 (Cropping2D)  (None, 160, 32, 1)           0         ['input[0][0]']
#
#  model_4 (Functional)        (None, 64)                   23456     ['cropping2d_21[0][0]',
#                                                                      'cropping2d_22[0][0]',
#                                                                      'cropping2d_23[0][0]',
#                                                                      'cropping2d_24[0][0]',
#                                                                      'cropping2d_25[0][0]']
#
#  concatenate_2 (Concatenate  (None, 320)                  0         ['model_4[0][0]',
#  )                                                                   'model_4[1][0]',
#                                                                      'model_4[2][0]',
#                                                                      'model_4[3][0]',
#                                                                      'model_4[4][0]']
#
#  reshape_2 (Reshape)         (None, 5, 64)                0         ['concatenate_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 5, 64)                12352     ['reshape_2[0][0]']
#
#  flatten_2 (Flatten)         (None, 320)                  0         ['conv1d_2[0][0]']
#
#  dense_6 (Dense)             (None, 64)                   20544     ['flatten_2[0][0]']
#
#  dense_7 (Dense)             (None, 32)                   2080      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 13)                   429       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 58861 (229.93 KB)
# Trainable params: 58861 (229.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import os

# === Directory for saving checkpoints ===
os.makedirs("energy_checkpoints_2", exist_ok=True)

# === Save best model with val_acc and epoch in name ===
checkpoint_cb = ModelCheckpoint(
    filepath="energy_checkpoints_2/best_model_epoch{epoch:02d}_valacc{val_accuracy:.4f}.h5",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1,
    mode='max'
)

# === Compile model ===
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# === Train and store history ===
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=[checkpoint_cb]
)
# Out:
# Epoch 1/50
# 51/51 [==============================] - ETA: 0s - loss: 2.4800 - accuracy: 0.1553
# Epoch 1: val_accuracy improved from -inf to 0.21503, saving model to energy_checkpoints_2\best_model_epoch01_valacc0.2150.h5
# 51/51 [==============================] - 226s 4s/step - loss: 2.4800 - accuracy: 0.1553 - val_loss: 2.1087 - val_accuracy: 0.2150
# Epoch 2/50
# c:\Users\ioana\anaconda3\envs\tiny_radar\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 51/51 [==============================] - ETA: 0s - loss: 1.6056 - accuracy: 0.4543
# Epoch 2: val_accuracy improved from 0.21503 to 0.49168, saving model to energy_checkpoints_2\best_model_epoch02_valacc0.4917.h5
# 51/51 [==============================] - 47s 924ms/step - loss: 1.6056 - accuracy: 0.4543 - val_loss: 1.3902 - val_accuracy: 0.4917
# Epoch 3/50
# 51/51 [==============================] - ETA: 0s - loss: 1.3028 - accuracy: 0.5227
# Epoch 3: val_accuracy improved from 0.49168 to 0.49476, saving model to energy_checkpoints_2\best_model_epoch03_valacc0.4948.h5
# 51/51 [==============================] - 46s 909ms/step - loss: 1.3028 - accuracy: 0.5227 - val_loss: 1.3046 - val_accuracy: 0.4948
# Epoch 4/50
# 51/51 [==============================] - ETA: 0s - loss: 1.1898 - accuracy: 0.5609
# Epoch 4: val_accuracy improved from 0.49476 to 0.55206, saving model to energy_checkpoints_2\best_model_epoch04_valacc0.5521.h5
# 51/51 [==============================] - 47s 923ms/step - loss: 1.1898 - accuracy: 0.5609 - val_loss: 1.1514 - val_accuracy: 0.5521
# Epoch 5/50
# 51/51 [==============================] - ETA: 0s - loss: 1.1024 - accuracy: 0.5864
# Epoch 5: val_accuracy improved from 0.55206 to 0.58965, saving model to energy_checkpoints_2\best_model_epoch05_valacc0.5896.h5
# 51/51 [==============================] - 46s 908ms/step - loss: 1.1024 - accuracy: 0.5864 - val_loss: 1.0978 - val_accuracy: 0.5896
# Epoch 6/50
# 51/51 [==============================] - ETA: 0s - loss: 1.0600 - accuracy: 0.5982
# Epoch 6: val_accuracy improved from 0.58965 to 0.59396, saving model to energy_checkpoints_2\best_model_epoch06_valacc0.5940.h5
# 51/51 [==============================] - 46s 906ms/step - loss: 1.0600 - accuracy: 0.5982 - val_loss: 1.0264 - val_accuracy: 0.5940
# Epoch 7/50
# 51/51 [==============================] - ETA: 0s - loss: 1.0057 - accuracy: 0.6135
# Epoch 7: val_accuracy improved from 0.59396 to 0.61738, saving model to energy_checkpoints_2\best_model_epoch07_valacc0.6174.h5
# 51/51 [==============================] - 46s 910ms/step - loss: 1.0057 - accuracy: 0.6135 - val_loss: 0.9829 - val_accuracy: 0.6174
# Epoch 8/50
# 51/51 [==============================] - ETA: 0s - loss: 0.9499 - accuracy: 0.6408
# Epoch 8: val_accuracy did not improve from 0.61738
# 51/51 [==============================] - 47s 917ms/step - loss: 0.9499 - accuracy: 0.6408 - val_loss: 1.2012 - val_accuracy: 0.5354
# Epoch 9/50
# 51/51 [==============================] - ETA: 0s - loss: 0.9457 - accuracy: 0.6378
# Epoch 9: val_accuracy improved from 0.61738 to 0.65989, saving model to energy_checkpoints_2\best_model_epoch09_valacc0.6599.h5
# 51/51 [==============================] - 50s 989ms/step - loss: 0.9457 - accuracy: 0.6378 - val_loss: 0.9013 - val_accuracy: 0.6599
# Epoch 10/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8862 - accuracy: 0.6630
# Epoch 10: val_accuracy did not improve from 0.65989
# 51/51 [==============================] - 51s 1s/step - loss: 0.8862 - accuracy: 0.6630 - val_loss: 0.9009 - val_accuracy: 0.6537
# Epoch 11/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8597 - accuracy: 0.6713
# Epoch 11: val_accuracy did not improve from 0.65989
# 51/51 [==============================] - 51s 1s/step - loss: 0.8597 - accuracy: 0.6713 - val_loss: 0.8913 - val_accuracy: 0.6587
# Epoch 12/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8548 - accuracy: 0.6693
# Epoch 12: val_accuracy improved from 0.65989 to 0.66852, saving model to energy_checkpoints_2\best_model_epoch12_valacc0.6685.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.8548 - accuracy: 0.6693 - val_loss: 0.8561 - val_accuracy: 0.6685
# Epoch 13/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8012 - accuracy: 0.6872
# Epoch 13: val_accuracy improved from 0.66852 to 0.69994, saving model to energy_checkpoints_2\best_model_epoch13_valacc0.6999.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.8012 - accuracy: 0.6872 - val_loss: 0.7971 - val_accuracy: 0.6999
# Epoch 14/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7877 - accuracy: 0.6912
# Epoch 14: val_accuracy improved from 0.69994 to 0.71411, saving model to energy_checkpoints_2\best_model_epoch14_valacc0.7141.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.7877 - accuracy: 0.6912 - val_loss: 0.7514 - val_accuracy: 0.7141
# Epoch 15/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7609 - accuracy: 0.7043
# Epoch 15: val_accuracy improved from 0.71411 to 0.72274, saving model to energy_checkpoints_2\best_model_epoch15_valacc0.7227.h5
# 51/51 [==============================] - 51s 994ms/step - loss: 0.7609 - accuracy: 0.7043 - val_loss: 0.7418 - val_accuracy: 0.7227
# Epoch 16/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.7057
# Epoch 16: val_accuracy did not improve from 0.72274
# 51/51 [==============================] - 51s 1s/step - loss: 0.7542 - accuracy: 0.7057 - val_loss: 0.7554 - val_accuracy: 0.7049
# Epoch 17/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7146 - accuracy: 0.7223
# Epoch 17: val_accuracy did not improve from 0.72274
# 51/51 [==============================] - 51s 1s/step - loss: 0.7146 - accuracy: 0.7223 - val_loss: 0.7425 - val_accuracy: 0.7079
# Epoch 18/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7494 - accuracy: 0.7020
# Epoch 18: val_accuracy did not improve from 0.72274
# 51/51 [==============================] - 51s 1s/step - loss: 0.7494 - accuracy: 0.7020 - val_loss: 0.7466 - val_accuracy: 0.7166
# Epoch 19/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.7326
# Epoch 19: val_accuracy improved from 0.72274 to 0.73136, saving model to energy_checkpoints_2\best_model_epoch19_valacc0.7314.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.6813 - accuracy: 0.7326 - val_loss: 0.7030 - val_accuracy: 0.7314
# Epoch 20/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.7299
# Epoch 20: val_accuracy improved from 0.73136 to 0.73383, saving model to energy_checkpoints_2\best_model_epoch20_valacc0.7338.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.6846 - accuracy: 0.7299 - val_loss: 0.6623 - val_accuracy: 0.7338
# Epoch 21/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.7365
# Epoch 21: val_accuracy improved from 0.73383 to 0.73444, saving model to energy_checkpoints_2\best_model_epoch21_valacc0.7344.h5
# 51/51 [==============================] - 51s 1000ms/step - loss: 0.6717 - accuracy: 0.7365 - val_loss: 0.7037 - val_accuracy: 0.7344
# Epoch 22/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.7334
# Epoch 22: val_accuracy did not improve from 0.73444
# 51/51 [==============================] - 51s 1s/step - loss: 0.6639 - accuracy: 0.7334 - val_loss: 0.6630 - val_accuracy: 0.7301
# Epoch 23/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.7391
# Epoch 23: val_accuracy did not improve from 0.73444
# 51/51 [==============================] - 51s 999ms/step - loss: 0.6425 - accuracy: 0.7391 - val_loss: 0.6703 - val_accuracy: 0.7307
# Epoch 24/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.7534
# Epoch 24: val_accuracy improved from 0.73444 to 0.74553, saving model to energy_checkpoints_2\best_model_epoch24_valacc0.7455.h5
# 51/51 [==============================] - 51s 999ms/step - loss: 0.6188 - accuracy: 0.7534 - val_loss: 0.6274 - val_accuracy: 0.7455
# Epoch 25/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6228 - accuracy: 0.7477
# Epoch 25: val_accuracy did not improve from 0.74553
# 51/51 [==============================] - 51s 1000ms/step - loss: 0.6228 - accuracy: 0.7477 - val_loss: 0.6424 - val_accuracy: 0.7289
# Epoch 26/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6081 - accuracy: 0.7524
# Epoch 26: val_accuracy improved from 0.74553 to 0.77203, saving model to energy_checkpoints_2\best_model_epoch26_valacc0.7720.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.6081 - accuracy: 0.7524 - val_loss: 0.5891 - val_accuracy: 0.7720
# Epoch 27/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5987 - accuracy: 0.7537
# Epoch 27: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5987 - accuracy: 0.7537 - val_loss: 0.6191 - val_accuracy: 0.7406
# Epoch 28/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.7599
# Epoch 28: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5957 - accuracy: 0.7599 - val_loss: 0.5949 - val_accuracy: 0.7548
# Epoch 29/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5963 - accuracy: 0.7520
# Epoch 29: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5963 - accuracy: 0.7520 - val_loss: 0.5905 - val_accuracy: 0.7560
# Epoch 30/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.7671
# Epoch 30: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5678 - accuracy: 0.7671 - val_loss: 0.5896 - val_accuracy: 0.7572
# Epoch 31/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5914 - accuracy: 0.7581
# Epoch 31: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5914 - accuracy: 0.7581 - val_loss: 0.5957 - val_accuracy: 0.7572
# Epoch 32/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.7647
# Epoch 32: val_accuracy did not improve from 0.77203
# 51/51 [==============================] - 51s 1s/step - loss: 0.5752 - accuracy: 0.7647 - val_loss: 0.5612 - val_accuracy: 0.7720
# Epoch 33/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.7738
# Epoch 33: val_accuracy improved from 0.77203 to 0.78497, saving model to energy_checkpoints_2\best_model_epoch33_valacc0.7850.h5
# 51/51 [==============================] - 52s 1s/step - loss: 0.5463 - accuracy: 0.7738 - val_loss: 0.5527 - val_accuracy: 0.7850
# Epoch 34/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5505 - accuracy: 0.7719
# Epoch 34: val_accuracy did not improve from 0.78497
# 51/51 [==============================] - 52s 1s/step - loss: 0.5505 - accuracy: 0.7719 - val_loss: 0.5712 - val_accuracy: 0.7591
# Epoch 35/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5395 - accuracy: 0.7833
# Epoch 35: val_accuracy improved from 0.78497 to 0.79174, saving model to energy_checkpoints_2\best_model_epoch35_valacc0.7917.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.5395 - accuracy: 0.7833 - val_loss: 0.5288 - val_accuracy: 0.7917
# Epoch 36/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.7878
# Epoch 36: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 51s 1s/step - loss: 0.5219 - accuracy: 0.7878 - val_loss: 0.5359 - val_accuracy: 0.7776
# Epoch 37/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5282 - accuracy: 0.7852
# Epoch 37: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 51s 1s/step - loss: 0.5282 - accuracy: 0.7852 - val_loss: 0.5437 - val_accuracy: 0.7831
# Epoch 38/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5210 - accuracy: 0.7904
# Epoch 38: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 51s 1s/step - loss: 0.5210 - accuracy: 0.7904 - val_loss: 0.5491 - val_accuracy: 0.7776
# Epoch 39/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.7787
# Epoch 39: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 52s 1s/step - loss: 0.5302 - accuracy: 0.7787 - val_loss: 0.5228 - val_accuracy: 0.7831
# Epoch 40/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5134 - accuracy: 0.7957
# Epoch 40: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 53s 1s/step - loss: 0.5134 - accuracy: 0.7957 - val_loss: 0.5379 - val_accuracy: 0.7850
# Epoch 41/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5121 - accuracy: 0.7849
# Epoch 41: val_accuracy did not improve from 0.79174
# 51/51 [==============================] - 51s 1s/step - loss: 0.5121 - accuracy: 0.7849 - val_loss: 0.5367 - val_accuracy: 0.7831
# Epoch 42/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4945 - accuracy: 0.7973
# Epoch 42: val_accuracy improved from 0.79174 to 0.79544, saving model to energy_checkpoints_2\best_model_epoch42_valacc0.7954.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.4945 - accuracy: 0.7973 - val_loss: 0.5016 - val_accuracy: 0.7954
# Epoch 43/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4918 - accuracy: 0.8026
# Epoch 43: val_accuracy did not improve from 0.79544
# 51/51 [==============================] - 51s 1s/step - loss: 0.4918 - accuracy: 0.8026 - val_loss: 0.5513 - val_accuracy: 0.7745
# Epoch 44/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.7900
# Epoch 44: val_accuracy improved from 0.79544 to 0.79914, saving model to energy_checkpoints_2\best_model_epoch44_valacc0.7991.h5
# 51/51 [==============================] - 52s 1s/step - loss: 0.5100 - accuracy: 0.7900 - val_loss: 0.5460 - val_accuracy: 0.7991
# Epoch 45/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.8043
# Epoch 45: val_accuracy did not improve from 0.79914
# 51/51 [==============================] - 51s 1s/step - loss: 0.4866 - accuracy: 0.8043 - val_loss: 0.5155 - val_accuracy: 0.7961
# Epoch 46/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8111
# Epoch 46: val_accuracy did not improve from 0.79914
# 51/51 [==============================] - 51s 1s/step - loss: 0.4726 - accuracy: 0.8111 - val_loss: 0.4937 - val_accuracy: 0.7979
# Epoch 47/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8115
# Epoch 47: val_accuracy improved from 0.79914 to 0.80037, saving model to energy_checkpoints_2\best_model_epoch47_valacc0.8004.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.4637 - accuracy: 0.8115 - val_loss: 0.4837 - val_accuracy: 0.8004
# Epoch 48/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.8046
# Epoch 48: val_accuracy improved from 0.80037 to 0.81762, saving model to energy_checkpoints_2\best_model_epoch48_valacc0.8176.h5
# 51/51 [==============================] - 51s 1s/step - loss: 0.4712 - accuracy: 0.8046 - val_loss: 0.4841 - val_accuracy: 0.8176
# Epoch 49/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4581 - accuracy: 0.8138
# Epoch 49: val_accuracy did not improve from 0.81762
# 51/51 [==============================] - 51s 1s/step - loss: 0.4581 - accuracy: 0.8138 - val_loss: 0.5058 - val_accuracy: 0.7930
# Epoch 50/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8191
# Epoch 50: val_accuracy did not improve from 0.81762
# 51/51 [==============================] - 51s 1000ms/step - loss: 0.4514 - accuracy: 0.8191 - val_loss: 0.4836 - val_accuracy: 0.8028

# %%
# load best keras model 
model = tf.keras.models.load_model("energy_checkpoints_2/best_model_epoch48_valacc0.8176.h5")

# %%
model.save('deployable_cnn_energy_model.h5')

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
exclude_labels = {}
label_to_idx = {label: idx for label, idx in label_map.items() if label not in exclude_labels}
idx_to_label = {v: k for k, v in label_to_idx.items()}

# Inverse mapping for lookup
valid_indices = set(label_to_idx.values())

y_true, y_pred = [], []
for X, y in val_gen:
    preds = model.predict(X)
    for true_label, pred_logits in zip(y, preds):
        if int(true_label) in valid_indices:
            y_true.append(int(true_label))
            y_pred.append(np.argmax(pred_logits))

# Reindex labels to remove gaps caused by excluded labels
original_to_new_idx = {old: new for new, old in enumerate(sorted(valid_indices))}
new_class_names = [idx_to_label[i] for i in sorted(valid_indices)]

# Remap y_true and y_pred
y_true_mapped = [original_to_new_idx[y] for y in y_true]
y_pred_mapped = [original_to_new_idx[y] for y in y_pred]

# Metrics
cm = confusion_matrix(y_true_mapped, y_pred_mapped)
acc = accuracy_score(y_true_mapped, y_pred_mapped)
report = classification_report(y_true_mapped, y_pred_mapped, target_names=new_class_names, digits=3)

# Normalize the confusion matrix row-wise to get percentages
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# Plot normalized confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=new_class_names, yticklabels=new_class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix 3CNN-1D Conv Energy  (Accuracy: {acc:.2%}) - Percentage")
plt.tight_layout()
plt.show()

# Print classification report
print(report)
# Out:
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 16ms/step
# 3/3 [==============================] - 0s 14ms/step
#                precision    recall  f1-score   support
#
#        Circle      0.917     0.992     0.953       123
#   FastSwipeRL      0.875     0.913     0.894       115
#     FingerRub      0.835     0.589     0.691       129
#  FingerSlider      0.766     0.792     0.779       149
#        NoHand      1.000     1.000     1.000       124
#      PalmHold      0.883     0.950     0.915       119
#      PalmTilt      0.874     0.929     0.901       127
#    PinchIndex      0.656     0.444     0.529       133
#    PinchPinky      0.535     0.684     0.601       133
#          Pull      0.831     0.880     0.855       117
#          Push      0.902     0.793     0.844       116
# RandomGesture      0.733     0.839     0.783       118
#   SlowSwipeRL      0.915     0.892     0.903       120
#
#      accuracy                          0.818      1623
#     macro avg      0.825     0.823     0.819      1623
#  weighted avg      0.821     0.818     0.814      1623

# %% [markdown]
# # Converting to TFLite

# %%
# Reload it to ensure clean state
model = tf.keras.models.load_model("deployable_cnn_energy_model.h5")
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.evaluate(val_gen)
# Out:
# 13/13 [==============================] - 7s 438ms/step - loss: 0.5506 - accuracy: 0.7831
# [0.5506397485733032, 0.7831177115440369]

# %%
# === Wrap with fixed batch size ===
fixed_input = tf.keras.Input(batch_input_shape=(1, 800, 32, 1), name="input")
fixed_output = model(fixed_input)
wrapped_model = tf.keras.Model(inputs=fixed_input, outputs=fixed_output)

# === Save as TFLite ===
converter = tf.lite.TFLiteConverter.from_keras_model(wrapped_model)
converter.inference_input_type = tf.float32
converter.inference_output_type = tf.float32

tflite_model = converter.convert()
with open("deployable_cnn_energy_model_float32.tflite", "wb") as f:
    f.write(tflite_model)

print(" Model wrapped and saved with fixed batch size: (1, 800, 32, 1)")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp7xb6lmep\assets
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp7xb6lmep\assets
#  Model wrapped and saved with fixed batch size: (1, 800, 32, 1)

# %%
# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="deployable_cnn_energy_model_float32.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to predict using TFLite
def predict_tflite_sequence(sequence):
    # Ensure float32 and normalized
    sequence = sequence.astype(np.float32)
    # Add batch dimension
    input_tensor = np.expand_dims(sequence, axis=0)  
    # Set tensor and invoke
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()
    # Extract prediction
    output = interpreter.get_tensor(output_details[0]['index'])
    return np.argmax(output, axis=1)[0]

# Evaluate on val set
y_true, y_pred = [], []
for X, y in val_gen:
    for i in range(len(X)):
        pred = predict_tflite_sequence(X[i])
        y_true.append(int(y[i]))
        y_pred.append(int(pred))

# Get full label list
idx_to_label = {v: k for k, v in label_map.items()}
class_names = [idx_to_label[i] for i in range(len(label_map))]

# Metrics
cm = confusion_matrix(y_true, y_pred)
acc = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred, target_names=class_names, digits=3)

# Normalize CM to show percentages
cm_percent = cm.astype(np.float32) / cm.sum(axis=1, keepdims=True) * 100

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"3D CNN-1D Energy Convolution Float 32 Confusion Matrix (Val Accuracy: {acc:.2%})")
plt.tight_layout()
plt.show()

# Print classification report
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        Circle      0.917     0.992     0.953       123
#   FastSwipeRL      0.875     0.913     0.894       115
#     FingerRub      0.835     0.589     0.691       129
#  FingerSlider      0.766     0.792     0.779       149
#        NoHand      1.000     1.000     1.000       124
#      PalmHold      0.883     0.950     0.915       119
#      PalmTilt      0.874     0.929     0.901       127
#    PinchIndex      0.656     0.444     0.529       133
#    PinchPinky      0.535     0.684     0.601       133
#          Pull      0.831     0.880     0.855       117
#          Push      0.902     0.793     0.844       116
# RandomGesture      0.733     0.839     0.783       118
#   SlowSwipeRL      0.915     0.892     0.903       120
#
#      accuracy                          0.818      1623
#     macro avg      0.825     0.823     0.819      1623
#  weighted avg      0.821     0.818     0.814      1623

# %% [markdown]
# # Quantizing to Int8

# %%
# === Fixed batch-size wrapper ===
fixed_input = tf.keras.Input(batch_input_shape=(1, 800, 32, 1), name="input")
fixed_output = model(fixed_input)
wrapped_model = tf.keras.Model(inputs=fixed_input, outputs=fixed_output)

# === Representative dataset: yield one sample with correct shape (1, 800, 32, 1) ===
def representative_dataset():
    for i in range(100):
        x, _ = train_gen[i]
        for sample in x:
            sample = sample.astype(np.float32)
            yield [np.expand_dims(sample, axis=0)]  # shape: (1, 800, 32, 1)

# === Convert model to full INT8 with fixed shape ===
converter = tf.lite.TFLiteConverter.from_keras_model(wrapped_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

# Convert and save
tflite_model = converter.convert()
with open("deployable_cnn_energy_model_int8.tflite", "wb") as f:
    f.write(tflite_model)

print("Full INT8 TFLite model saved with fixed batch size: (1, 800, 32, 1)")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmpe1zuyl7f\assets
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmpe1zuyl7f\assets
# c:\Users\ioana\anaconda3\envs\tiny_radar\lib\site-packages\tensorflow\lite\python\convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Full INT8 TFLite model saved with fixed batch size: (1, 800, 32, 1)

# %% [markdown]
# Testing

# %%
# Load TFLite model
interpreter = tf.lite.Interpreter(model_path=r"C:\Users\ioana\Documents\VS Projects\ML-on-Microcontrollers-Project-Ioana-Gidiuta\Code\model_training_grayscale_images\deployable_cnn_energy_model_int8.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to predict using TFLite
def predict_tflite_sequence(sequence):
    # Get scale and zero-point for quantization
    scale, zero_point = input_details[0]['quantization']

    # Normalize input (assuming it was float32 [0,1])
    sequence = sequence.astype(np.float32)

    # Quantize to int8
    sequence_q = (sequence / scale + zero_point).astype(np.int8)
    input_tensor = np.expand_dims(sequence_q, axis=0)  # Add batch dim

    # Set and run
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()

    # Dequantize output if needed
    output_data = interpreter.get_tensor(output_details[0]['index'])
    return np.argmax(output_data, axis=1)[0]

# Evaluate on val set
y_true, y_pred = [], []
for X, y in val_gen:
    for i in range(len(X)):
        pred = predict_tflite_sequence(X[i])
        y_true.append(int(y[i]))
        y_pred.append(int(pred))

# Get full label list
idx_to_label = {v: k for k, v in label_map.items()}
class_names = [idx_to_label[i] for i in range(len(label_map))]

# Metrics
cm = confusion_matrix(y_true, y_pred)
acc = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred, target_names=class_names, digits=3)

# Normalize CM to show percentages
cm_percent = cm.astype(np.float32) / cm.sum(axis=1, keepdims=True) * 100

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"3D CNN-1D Convolution Int8 Confusion Matrix (Val Accuracy: {acc:.2%})")
plt.tight_layout()
plt.show()

# Print classification report
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        Circle      0.917     0.992     0.953       123
#   FastSwipeRL      0.881     0.904     0.893       115
#     FingerRub      0.748     0.620     0.678       129
#  FingerSlider      0.743     0.758     0.751       149
#        NoHand      1.000     1.000     1.000       124
#      PalmHold      0.887     0.924     0.905       119
#      PalmTilt      0.881     0.937     0.908       127
#    PinchIndex      0.537     0.496     0.516       133
#    PinchPinky      0.531     0.519     0.525       133
#          Pull      0.771     0.949     0.851       117
#          Push      0.965     0.707     0.816       116
# RandomGesture      0.748     0.831     0.787       118
#   SlowSwipeRL      0.906     0.883     0.895       120
#
#      accuracy                          0.803      1623
#     macro avg      0.809     0.809     0.806      1623
#  weighted avg      0.803     0.803     0.800      1623

# %%
# Load TFLite model
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize

interpreter = tf.lite.Interpreter(model_path=r"C:\Users\ioana\Documents\VS Projects\ML-on-Microcontrollers-Project-Ioana-Gidiuta\Code\model_training_grayscale_images\deployable_cnn_energy_model_int8.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def predict_tflite_proba(sequence):
    # Quantization parameters for the input
    scale, zero_point = input_details[0]['quantization']
    
    # Quantize float32 input to int8
    input_tensor = (sequence / scale + zero_point).astype(np.int8)
    input_tensor = np.expand_dims(input_tensor, axis=0)  # Add batch dimension

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()

    # Dequantize output (optional but useful for ROC/PR curves)
    output_data = interpreter.get_tensor(output_details[0]['index'])[0]
    out_scale, out_zero_point = output_details[0]['quantization']
    output_dequant = (output_data.astype(np.float32) - out_zero_point) * out_scale

    return output_dequant

# Gather predictions and scores
y_true, y_scores = [], []
for X_batch, y_batch in val_gen:
    for i in range(len(X_batch)):
        y_true.append(int(y_batch[i]))
        y_scores.append(predict_tflite_proba(X_batch[i]))

y_true = np.array(y_true)
y_scores = np.array(y_scores)
y_pred = np.argmax(y_scores, axis=1)

# Convert labels to one-hot for metrics
n_classes = len(label_map)
y_true_bin = label_binarize(y_true, classes=range(n_classes))

# ROC Curve
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curves 3D CNN-1D Convolution Int8")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# Precision-Recall Curve
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
    avg_precision = average_precision_score(y_true_bin[:, i], y_scores[:, i])
    plt.plot(recall, precision, label=f"Class {i} (AP = {avg_precision:.2f})")
plt.title("Precision-Recall Curves 3D CNN-1D Convolution Int8")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# Confidence Score Distribution
conf_scores = np.max(y_scores, axis=1)
plt.figure(figsize=(10, 6))
sns.histplot(conf_scores, bins=30, kde=True)
plt.title("Confidence Score Distribution 3D CNN-1D Convolution Int8")
plt.xlabel("Confidence")
plt.ylabel("Frequency")
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Making Data for Validation

# %%
def save_float32_csv_for_validation_one_file(generator, label_map, output_dir="csv_validation_data", samples_per_gesture=3):
    import os
    import numpy as np

    os.makedirs(output_dir, exist_ok=True)

    gesture_counts = {label: 0 for label in label_map.values()}
    all_inputs = []
    all_labels = []

    num_classes = len(label_map)

    for X_batch, y_batch in generator:
        for i in range(len(y_batch)):
            label = int(y_batch[i])
            if gesture_counts[label] >= samples_per_gesture:
                continue

            # Flatten input (already in [0, 1] float32)
            input_data = X_batch[i]
            flat_input = input_data.flatten()
            all_inputs.append(flat_input)

            # One-hot encode label
            one_hot = np.zeros(num_classes, dtype=int)
            one_hot[label] = 1
            all_labels.append(one_hot)

            gesture_counts[label] += 1

        if all(count >= samples_per_gesture for count in gesture_counts.values()):
            break

    # Save to CSV
    input_path = os.path.join(output_dir, "all_inputs.csv")
    label_path = os.path.join(output_dir, "all_labels.csv")

    np.savetxt(input_path, all_inputs, fmt='%.6f', delimiter=',')
    np.savetxt(label_path, all_labels, fmt='%d', delimiter=',')

    print(f"Saved {len(all_inputs)} samples to:")
    print(f"  → {input_path}")
    print(f"  → {label_path}")

# %%
save_float32_csv_for_validation_one_file(val_gen, label_map, output_dir="3_cnn_1dc_eng_val_data_float32_ten", samples_per_gesture=10)
# Out:
# Saved 130 samples to:
#   → 3_cnn_1dc_eng_val_data_float32_ten\all_inputs.csv
#   → 3_cnn_1dc_eng_val_data_float32_ten\all_labels.csv
