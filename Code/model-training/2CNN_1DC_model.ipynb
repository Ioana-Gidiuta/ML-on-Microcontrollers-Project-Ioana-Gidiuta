# %%
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_auto_jit=0'
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import Sequence
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from glob import glob

# %%
# Constants

RTM_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\RTM_images'
DTM_PATH = r'\\ML-on-Microcontrollers-Project-Ioana-Gidiuta\\Datasets\\11G-features\\DTM_images'

IMG_SIZE = (32, 32)
SEQ_LEN = 5

# %%
# === Utility ===
def load_img_uint8(path):
    img = load_img(path, color_mode='grayscale', target_size=IMG_SIZE)
    return img_to_array(img).astype(np.uint8)

# === Index Dataset (RTM + DTM only) ===
def index_sequences(rtm_path, dtm_path, seq_len=5, exclude=None):
    train, test, gestures = [], [], set()
    exclude = set(exclude or [])
    for person in sorted(os.listdir(rtm_path)):
        target = test if person in exclude else train
        for session in os.listdir(os.path.join(rtm_path, person)):
            for gesture in os.listdir(os.path.join(rtm_path, person, session)):
                rtm_files = sorted(glob(os.path.join(rtm_path, person, session, gesture, '*.png')))
                dtm_files = sorted(glob(os.path.join(dtm_path, person, session, gesture, '*.png')))
                n = min(len(rtm_files), len(dtm_files))
                gestures.add(gesture)
                for i in range(n - seq_len + 1):
                    target.append({
                        'rtm': rtm_files[i:i+seq_len],
                        'dtm': dtm_files[i:i+seq_len],
                        'label': gesture
                    })
    label_map = {g: i for i, g in enumerate(sorted(gestures))}
    train_data, val_data = train_test_split(train, test_size=0.2, random_state=42)
    return train_data, val_data, test, label_map

# === Data Generator (RTM + DTM only) ===
class SingleInputSequence(Sequence):
    def __init__(self, samples, label_map, batch_size=64, seq_len=5, shuffle_data=False):
        self.samples = samples
        self.label_map = label_map
        self.batch_size = batch_size
        self.seq_len = seq_len
        self.shuffle_data = shuffle_data
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.samples) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle_data:
            self.samples = shuffle(self.samples)

    def __getitem__(self, idx):
        batch = self.samples[idx * self.batch_size: (idx + 1) * self.batch_size]
        X, y = [], []
        for sample in batch:
            rtm = [load_img_uint8(p) for p in sample['rtm']]
            dtm = [load_img_uint8(p) for p in sample['dtm']]
            sequence = np.concatenate(rtm + dtm, axis=0)  # shape: (10*32, 32, 1) = (320, 32, 1)
            X.append(sequence)
            y.append(self.label_map[sample['label']])
        X = np.array(X).astype(np.float32) / 255.0
        return X, np.array(y)

# %%
def build_stm32_deployable_model(input_shape=(320, 32, 1), num_classes=13):
    inputs = tf.keras.Input(shape=input_shape, name="input")

    # === 1. Split Input ===
    rtm = layers.Cropping2D(((0, 160), (0, 0)))(inputs)     # 0:160
    dtm = layers.Cropping2D(((160, 0), (0, 0)))(inputs)     # 160:320

    def cnn_branch():
        inp = tf.keras.Input(shape=(160, 32, 1))
        x = layers.Conv2D(16, 3, activation='relu', padding='same')(inp)
        x = layers.DepthwiseConv2D(3, activation='relu', padding='same')(x)
        x = layers.MaxPooling2D(2)(x)  # 80x16x16

        x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
        x = layers.MaxPooling2D(2)(x)  # 40x8x32

        x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
        x = layers.GlobalAveragePooling2D()(x)  # -> (64,)
        return tf.keras.Model(inp, x)

    branch = cnn_branch()

    feat_rtm = branch(rtm)
    feat_dtm = branch(dtm)

    # === 2. Temporal Fusion (simulated LSTM) ===
    x = layers.Concatenate()([feat_rtm, feat_dtm])  # (128,)
    x = layers.Reshape((2, 64))(x)  # (2, 64)

    x = layers.Conv1D(64, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.Flatten()(x)  # instead of GlobalAvgPool1D

    # === 3. MLP Head ===
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return tf.keras.Model(inputs, outputs)

# %%
excluded = {f'p0_{i}' for i in range(15, 21)}  # Exclude p0_15 to p0_20
train_samples, val_samples, test_samples, label_map = index_sequences(
    RTM_PATH, DTM_PATH, seq_len=SEQ_LEN, exclude=excluded
)

# Instantiate generators
train_gen = SingleInputSequence(train_samples, label_map, batch_size=128, shuffle_data=True)
val_gen = SingleInputSequence(val_samples, label_map, batch_size=128, shuffle_data=False)

# %%
model = build_stm32_deployable_model(input_shape=(320, 32, 1), num_classes=13)
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 320, 32, 1)]         0         []
#
#  cropping2d_8 (Cropping2D)   (None, 160, 32, 1)           0         ['input[0][0]']
#
#  cropping2d_9 (Cropping2D)   (None, 160, 32, 1)           0         ['input[0][0]']
#
#  model_14 (Functional)       (None, 64)                   23456     ['cropping2d_8[0][0]',
#                                                                      'cropping2d_9[0][0]']
#
#  concatenate_4 (Concatenate  (None, 128)                  0         ['model_14[0][0]',
#  )                                                                   'model_14[1][0]']
#
#  reshape_4 (Reshape)         (None, 2, 64)                0         ['concatenate_4[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 2, 64)                12352     ['reshape_4[0][0]']
#
#  flatten_4 (Flatten)         (None, 128)                  0         ['conv1d_4[0][0]']
#
#  dense_18 (Dense)            (None, 64)                   8256      ['flatten_4[0][0]']
#
#  dense_19 (Dense)            (None, 32)                   2080      ['dense_18[0][0]']
#
#  dense_20 (Dense)            (None, 13)                   429       ['dense_19[0][0]']
#
# ==================================================================================================
# Total params: 46573 (181.93 KB)
# Trainable params: 46573 (181.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import Callback

# === 1. Create checkpoint folder ===
checkpoint_dir = 'Models/checkpoint_2CNN_checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

# === 2. Custom Callback to Save Model Per Epoch with val_accuracy ===
class SaveBestWithAcc(Callback):
    def __init__(self, base_path):
        super().__init__()
        self.best_val_acc = 0.0
        self.base_path = base_path

    def on_epoch_end(self, epoch, logs=None):
        val_acc = logs.get('val_accuracy')
        if val_acc is not None and val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            filename = f"model_epoch{epoch+1:02d}_valacc{val_acc:.4f}.h5"
            path = os.path.join(self.base_path, filename)
            self.model.save(path)
            print(f"Saved improved model to: {path}")

# === 3. Compile model ===
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# === 4. Train with custom saving callback ===
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=[SaveBestWithAcc(checkpoint_dir)]
)

# === 5. Plot accuracy ===
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
#plt.savefig(os.path.join(checkpoint_dir, 'accuracy_curve.png'))
plt.show()

# === 6. Plot loss ===
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
#plt.savefig(os.path.join(checkpoint_dir, 'loss_curve.png'))
plt.show()
# Out:
# Epoch 1/50
# 51/51 [==============================] - ETA: 0s - loss: 2.4600 - accuracy: 0.1590Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch01_valacc0.2945.h5
# 51/51 [==============================] - 24s 464ms/step - loss: 2.4600 - accuracy: 0.1590 - val_loss: 2.0772 - val_accuracy: 0.2945
# Epoch 2/50
# c:\Users\ioana\anaconda3\envs\tiny_radar\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 51/51 [==============================] - ETA: 0s - loss: 1.7957 - accuracy: 0.3586Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch02_valacc0.4023.h5
# 51/51 [==============================] - 21s 421ms/step - loss: 1.7957 - accuracy: 0.3586 - val_loss: 1.6073 - val_accuracy: 0.4023
# Epoch 3/50
# 51/51 [==============================] - 22s 423ms/step - loss: 1.5890 - accuracy: 0.4092 - val_loss: 1.5706 - val_accuracy: 0.3894
# Epoch 4/50
# 51/51 [==============================] - ETA: 0s - loss: 1.5360 - accuracy: 0.4135Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch04_valacc0.4030.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 1.5360 - accuracy: 0.4135 - val_loss: 1.5152 - val_accuracy: 0.4030
# Epoch 5/50
# 51/51 [==============================] - ETA: 0s - loss: 1.5146 - accuracy: 0.4253Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch05_valacc0.4301.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 1.5146 - accuracy: 0.4253 - val_loss: 1.4960 - val_accuracy: 0.4301
# Epoch 6/50
# 51/51 [==============================] - ETA: 0s - loss: 1.4555 - accuracy: 0.4481Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch06_valacc0.4442.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 1.4555 - accuracy: 0.4481 - val_loss: 1.4462 - val_accuracy: 0.4442
# Epoch 7/50
# 51/51 [==============================] - ETA: 0s - loss: 1.4057 - accuracy: 0.4723Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch07_valacc0.4904.h5
# 51/51 [==============================] - 21s 414ms/step - loss: 1.4057 - accuracy: 0.4723 - val_loss: 1.3892 - val_accuracy: 0.4904
# Epoch 8/50
# 51/51 [==============================] - ETA: 0s - loss: 1.3170 - accuracy: 0.5052Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch08_valacc0.5065.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 1.3170 - accuracy: 0.5052 - val_loss: 1.2840 - val_accuracy: 0.5065
# Epoch 9/50
# 51/51 [==============================] - ETA: 0s - loss: 1.2342 - accuracy: 0.5323Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch09_valacc0.5447.h5
# 51/51 [==============================] - 21s 420ms/step - loss: 1.2342 - accuracy: 0.5323 - val_loss: 1.1983 - val_accuracy: 0.5447
# Epoch 10/50
# 51/51 [==============================] - ETA: 0s - loss: 1.1430 - accuracy: 0.5728Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch10_valacc0.5699.h5
# 51/51 [==============================] - 21s 422ms/step - loss: 1.1430 - accuracy: 0.5728 - val_loss: 1.1285 - val_accuracy: 0.5699
# Epoch 11/50
# 51/51 [==============================] - ETA: 0s - loss: 1.0850 - accuracy: 0.5887Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch11_valacc0.5872.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 1.0850 - accuracy: 0.5887 - val_loss: 1.1001 - val_accuracy: 0.5872
# Epoch 12/50
# 51/51 [==============================] - ETA: 0s - loss: 1.0296 - accuracy: 0.5976Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch12_valacc0.6014.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 1.0296 - accuracy: 0.5976 - val_loss: 1.0351 - val_accuracy: 0.6014
# Epoch 13/50
# 51/51 [==============================] - ETA: 0s - loss: 0.9858 - accuracy: 0.6172Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch13_valacc0.6272.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 0.9858 - accuracy: 0.6172 - val_loss: 0.9825 - val_accuracy: 0.6272
# Epoch 14/50
# 51/51 [==============================] - ETA: 0s - loss: 0.9498 - accuracy: 0.6331Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch14_valacc0.6377.h5
# 51/51 [==============================] - 21s 416ms/step - loss: 0.9498 - accuracy: 0.6331 - val_loss: 0.9714 - val_accuracy: 0.6377
# Epoch 15/50
# 51/51 [==============================] - 21s 415ms/step - loss: 0.9249 - accuracy: 0.6429 - val_loss: 0.9745 - val_accuracy: 0.6291
# Epoch 16/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8983 - accuracy: 0.6520Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch16_valacc0.6519.h5
# 51/51 [==============================] - 21s 415ms/step - loss: 0.8983 - accuracy: 0.6520 - val_loss: 0.9295 - val_accuracy: 0.6519
# Epoch 17/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8684 - accuracy: 0.6681Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch17_valacc0.6636.h5
# 51/51 [==============================] - 21s 418ms/step - loss: 0.8684 - accuracy: 0.6681 - val_loss: 0.8935 - val_accuracy: 0.6636
# Epoch 18/50
# 51/51 [==============================] - ETA: 0s - loss: 0.8269 - accuracy: 0.6824Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch18_valacc0.6661.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 0.8269 - accuracy: 0.6824 - val_loss: 0.8823 - val_accuracy: 0.6661
# Epoch 19/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.8073 - accuracy: 0.6918 - val_loss: 0.8792 - val_accuracy: 0.6513
# Epoch 20/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7906 - accuracy: 0.6944Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch20_valacc0.6759.h5
# 51/51 [==============================] - 21s 421ms/step - loss: 0.7906 - accuracy: 0.6944 - val_loss: 0.8210 - val_accuracy: 0.6759
# Epoch 21/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7798 - accuracy: 0.6964Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch21_valacc0.7116.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 0.7798 - accuracy: 0.6964 - val_loss: 0.7809 - val_accuracy: 0.7116
# Epoch 22/50
# 51/51 [==============================] - 21s 415ms/step - loss: 0.7531 - accuracy: 0.7066 - val_loss: 0.8025 - val_accuracy: 0.6999
# Epoch 23/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.7430 - accuracy: 0.7110 - val_loss: 0.7964 - val_accuracy: 0.6975
# Epoch 24/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7166 - accuracy: 0.7215Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch24_valacc0.7270.h5
# 51/51 [==============================] - 21s 422ms/step - loss: 0.7166 - accuracy: 0.7215 - val_loss: 0.7427 - val_accuracy: 0.7270
# Epoch 25/50
# 51/51 [==============================] - 24s 478ms/step - loss: 0.6916 - accuracy: 0.7312 - val_loss: 0.7174 - val_accuracy: 0.7258
# Epoch 26/50
# 51/51 [==============================] - ETA: 0s - loss: 0.7105 - accuracy: 0.7217Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch26_valacc0.7320.h5
# 51/51 [==============================] - 22s 437ms/step - loss: 0.7105 - accuracy: 0.7217 - val_loss: 0.7236 - val_accuracy: 0.7320
# Epoch 27/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.7413Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch27_valacc0.7412.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 0.6722 - accuracy: 0.7413 - val_loss: 0.6870 - val_accuracy: 0.7412
# Epoch 28/50
# 51/51 [==============================] - 21s 418ms/step - loss: 0.6785 - accuracy: 0.7343 - val_loss: 0.7054 - val_accuracy: 0.7221
# Epoch 29/50
# 51/51 [==============================] - 21s 415ms/step - loss: 0.6566 - accuracy: 0.7448 - val_loss: 0.6887 - val_accuracy: 0.7412
# Epoch 30/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.7520Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch30_valacc0.7443.h5
# 51/51 [==============================] - 21s 415ms/step - loss: 0.6326 - accuracy: 0.7520 - val_loss: 0.6601 - val_accuracy: 0.7443
# Epoch 31/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6449 - accuracy: 0.7507Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch31_valacc0.7591.h5
# 51/51 [==============================] - 21s 417ms/step - loss: 0.6449 - accuracy: 0.7507 - val_loss: 0.6305 - val_accuracy: 0.7591
# Epoch 32/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.6330 - accuracy: 0.7480 - val_loss: 0.7094 - val_accuracy: 0.7153
# Epoch 33/50
# 51/51 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.7608Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch33_valacc0.7726.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 0.6080 - accuracy: 0.7608 - val_loss: 0.6179 - val_accuracy: 0.7726
# Epoch 34/50
# 51/51 [==============================] - 21s 416ms/step - loss: 0.6017 - accuracy: 0.7624 - val_loss: 0.6686 - val_accuracy: 0.7307
# Epoch 35/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.5981 - accuracy: 0.7624 - val_loss: 0.6337 - val_accuracy: 0.7461
# Epoch 36/50
# 51/51 [==============================] - 21s 419ms/step - loss: 0.5814 - accuracy: 0.7702 - val_loss: 0.6197 - val_accuracy: 0.7585
# Epoch 37/50
# 51/51 [==============================] - 21s 415ms/step - loss: 0.5785 - accuracy: 0.7704 - val_loss: 0.6655 - val_accuracy: 0.7449
# Epoch 38/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.5596 - accuracy: 0.7812 - val_loss: 0.5877 - val_accuracy: 0.7726
# Epoch 39/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7813Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch39_valacc0.7776.h5
# 51/51 [==============================] - 21s 416ms/step - loss: 0.5452 - accuracy: 0.7813 - val_loss: 0.5817 - val_accuracy: 0.7776
# Epoch 40/50
# 51/51 [==============================] - 21s 415ms/step - loss: 0.5442 - accuracy: 0.7852 - val_loss: 0.6043 - val_accuracy: 0.7708
# Epoch 41/50
# 51/51 [==============================] - 21s 416ms/step - loss: 0.5414 - accuracy: 0.7836 - val_loss: 0.5846 - val_accuracy: 0.7677
# Epoch 42/50
# 51/51 [==============================] - 22s 425ms/step - loss: 0.5199 - accuracy: 0.7930 - val_loss: 0.6040 - val_accuracy: 0.7702
# Epoch 43/50
# 51/51 [==============================] - ETA: 0s - loss: 0.5191 - accuracy: 0.7944Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch43_valacc0.7868.h5
# 51/51 [==============================] - 21s 419ms/step - loss: 0.5191 - accuracy: 0.7944 - val_loss: 0.5595 - val_accuracy: 0.7868
# Epoch 44/50
# 51/51 [==============================] - 21s 419ms/step - loss: 0.5302 - accuracy: 0.7866 - val_loss: 0.5779 - val_accuracy: 0.7770
# Epoch 45/50
# 51/51 [==============================] - 21s 417ms/step - loss: 0.5086 - accuracy: 0.7989 - val_loss: 0.5825 - val_accuracy: 0.7770
# Epoch 46/50
# 51/51 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.8029Saved improved model to: Models/checkpoint_2CNN_checkpoints\model_epoch46_valacc0.7985.h5
# 51/51 [==============================] - 21s 415ms/step - loss: 0.4948 - accuracy: 0.8029 - val_loss: 0.5196 - val_accuracy: 0.7985
# Epoch 47/50
# 51/51 [==============================] - 22s 428ms/step - loss: 0.4935 - accuracy: 0.8063 - val_loss: 0.5702 - val_accuracy: 0.7776
# Epoch 48/50
# 51/51 [==============================] - 21s 422ms/step - loss: 0.4897 - accuracy: 0.8024 - val_loss: 0.5405 - val_accuracy: 0.7961
# Epoch 49/50
# 51/51 [==============================] - 21s 422ms/step - loss: 0.4891 - accuracy: 0.8098 - val_loss: 0.5738 - val_accuracy: 0.7776
# Epoch 50/50
# 51/51 [==============================] - 21s 416ms/step - loss: 0.4844 - accuracy: 0.8120 - val_loss: 0.5465 - val_accuracy: 0.7905

# %%
# load best model from given path
model = tf.keras.models.load_model(r"\Code\model_training_grayscale_images\Models\checkpoint_2CNN_checkpoints\model_epoch46_valacc0.7985.h5")
model.save('deployable_2cnn_model.h5')

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

exclude_labels = {}
label_to_idx = {label: idx for label, idx in label_map.items() if label not in exclude_labels}
idx_to_label = {v: k for k, v in label_to_idx.items()}

# Inverse mapping for lookup
valid_indices = set(label_to_idx.values())

y_true, y_pred = [], []
for X, y in val_gen:
    preds = model.predict(X)
    for true_label, pred_logits in zip(y, preds):
        if int(true_label) in valid_indices:
            y_true.append(int(true_label))
            y_pred.append(np.argmax(pred_logits))

# Reindex labels to remove gaps caused by excluded labels
original_to_new_idx = {old: new for new, old in enumerate(sorted(valid_indices))}
new_class_names = [idx_to_label[i] for i in sorted(valid_indices)]

# Remap y_true and y_pred
y_true_mapped = [original_to_new_idx[y] for y in y_true]
y_pred_mapped = [original_to_new_idx[y] for y in y_pred]

# Metrics
cm = confusion_matrix(y_true_mapped, y_pred_mapped)
acc = accuracy_score(y_true_mapped, y_pred_mapped)
report = classification_report(y_true_mapped, y_pred_mapped, target_names=new_class_names, digits=3)

# Normalize the confusion matrix row-wise to get percentages
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# Plot normalized confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=new_class_names, yticklabels=new_class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix (Accuracy: {acc:.2%}) - Percentage")
plt.tight_layout()
plt.show()

# Print classification report
print(report)
# Out:
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 8ms/step
#                precision    recall  f1-score   support
#
#        Circle      0.935     0.935     0.935       123
#   FastSwipeRL      0.872     0.887     0.879       115
#     FingerRub      0.808     0.651     0.721       129
#  FingerSlider      0.772     0.839     0.804       149
#        NoHand      0.976     1.000     0.988       124
#      PalmHold      0.933     0.933     0.933       119
#      PalmTilt      0.919     0.890     0.904       127
#    PinchIndex      0.583     0.632     0.606       133
#    PinchPinky      0.581     0.564     0.573       133
#          Pull      0.677     0.769     0.720       117
#          Push      0.716     0.672     0.693       116
# RandomGesture      0.790     0.797     0.793       118
#   SlowSwipeRL      0.886     0.842     0.863       120
#
#      accuracy                          0.799      1623
#     macro avg      0.804     0.801     0.801      1623
#  weighted avg      0.801     0.799     0.798      1623

# %% [markdown]
# # Converting to TFLite

# %%
# === Wrap with fixed batch size ===
fixed_input = tf.keras.Input(batch_input_shape=(1, 320, 32, 1), name="input")
fixed_output = model(fixed_input)
wrapped_model = tf.keras.Model(inputs=fixed_input, outputs=fixed_output)

# === Save as TFLite ===
converter = tf.lite.TFLiteConverter.from_keras_model(wrapped_model)
converter.inference_input_type = tf.float32
converter.inference_output_type = tf.float32

tflite_model = converter.convert()
with open("deployable_2cnn_model_float32.tflite", "wb") as f:
    f.write(tflite_model)

print(" Model wrapped and saved with fixed batch size: (1, 320, 32, 1)")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp9gdc1fvj\assets
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp9gdc1fvj\assets
#  Model wrapped and saved with fixed batch size: (1, 320, 32, 1)

# %%
# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="deployable_2cnn_model_float32.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to predict using TFLite
def predict_tflite_sequence(sequence):
    # Ensure float32 and normalized
    sequence = sequence.astype(np.float32)
    # Add batch dimension
    input_tensor = np.expand_dims(sequence, axis=0)  
    # Set tensor and invoke
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()
    # Extract prediction
    output = interpreter.get_tensor(output_details[0]['index'])
    return np.argmax(output, axis=1)[0]

# Evaluate on val set
y_true, y_pred = [], []
for X, y in val_gen:
    for i in range(len(X)):
        pred = predict_tflite_sequence(X[i])
        y_true.append(int(y[i]))
        y_pred.append(int(pred))

# Get full label list
idx_to_label = {v: k for k, v in label_map.items()}
class_names = [idx_to_label[i] for i in range(len(label_map))]

# Metrics
cm = confusion_matrix(y_true, y_pred)
acc = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred, target_names=class_names, digits=3)

# Normalize CM to show percentages
cm_percent = cm.astype(np.float32) / cm.sum(axis=1, keepdims=True) * 100

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"2 CNN-1D Convolution Float 32 Confusion Matrix (Val Accuracy: {acc:.2%})")
plt.tight_layout()
plt.show()

# Print classification report
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        Circle      0.935     0.935     0.935       123
#   FastSwipeRL      0.872     0.887     0.879       115
#     FingerRub      0.808     0.651     0.721       129
#  FingerSlider      0.772     0.839     0.804       149
#        NoHand      0.976     1.000     0.988       124
#      PalmHold      0.933     0.933     0.933       119
#      PalmTilt      0.919     0.890     0.904       127
#    PinchIndex      0.583     0.632     0.606       133
#    PinchPinky      0.581     0.564     0.573       133
#          Pull      0.677     0.769     0.720       117
#          Push      0.716     0.672     0.693       116
# RandomGesture      0.790     0.797     0.793       118
#   SlowSwipeRL      0.886     0.842     0.863       120
#
#      accuracy                          0.799      1623
#     macro avg      0.804     0.801     0.801      1623
#  weighted avg      0.801     0.799     0.798      1623

# %% [markdown]
# # Quantizing to Int8

# %%
# === Fixed batch-size wrapper ===
fixed_input = tf.keras.Input(batch_input_shape=(1, 320, 32, 1), name="input")
fixed_output = model(fixed_input)
wrapped_model = tf.keras.Model(inputs=fixed_input, outputs=fixed_output)

# === Representative dataset: yield one sample with correct shape (1, 480, 32, 1) ===
def representative_dataset():
    for i in range(100):
        x, _ = train_gen[i]
        for sample in x:
            sample = sample.astype(np.float32)
            yield [np.expand_dims(sample, axis=0)]  # shape: (1, 480, 32, 1)

# === Convert model to full INT8 with fixed shape ===
converter = tf.lite.TFLiteConverter.from_keras_model(wrapped_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

# Convert and save
tflite_model = converter.convert()
with open("deployable_2cnn_model_int8.tflite", "wb") as f:
    f.write(tflite_model)

print("Full INT8 TFLite model saved with fixed batch size: (1, 320, 32, 1)")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp3jgkzamo\assets
# INFO:tensorflow:Assets written to: C:\Users\ioana\AppData\Local\Temp\tmp3jgkzamo\assets
# c:\Users\ioana\anaconda3\envs\tiny_radar\lib\site-packages\tensorflow\lite\python\convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Full INT8 TFLite model saved with fixed batch size: (1, 320, 32, 1)

# %% [markdown]
# Testing

# %%
# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="deployable_2cnn_model_int8.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to predict using TFLite
def predict_tflite_sequence(sequence):
    # Get scale and zero-point for quantization
    scale, zero_point = input_details[0]['quantization']

    # Normalize input (assuming it was float32 [0,1])
    sequence = sequence.astype(np.float32)

    # Quantize to int8
    sequence_q = (sequence / scale + zero_point).astype(np.int8)
    input_tensor = np.expand_dims(sequence_q, axis=0)  # Add batch dim

    # Set and run
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()

    # Dequantize output if needed
    output_data = interpreter.get_tensor(output_details[0]['index'])
    return np.argmax(output_data, axis=1)[0]

# Evaluate on val set
y_true, y_pred = [], []
for X, y in val_gen:
    for i in range(len(X)):
        pred = predict_tflite_sequence(X[i])
        y_true.append(int(y[i]))
        y_pred.append(int(pred))

# Get full label list
idx_to_label = {v: k for k, v in label_map.items()}
class_names = [idx_to_label[i] for i in range(len(label_map))]

# Metrics
cm = confusion_matrix(y_true, y_pred)
acc = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred, target_names=class_names, digits=3)

# Normalize CM to show percentages
cm_percent = cm.astype(np.float32) / cm.sum(axis=1, keepdims=True) * 100

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm_percent, annot=True, fmt=".1f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"2 CNN-1D Convolution Int8 Confusion Matrix (Val Accuracy: {acc:.2%})")
plt.tight_layout()
plt.show()

# Print classification report
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#        Circle      0.943     0.935     0.939       123
#   FastSwipeRL      0.872     0.887     0.879       115
#     FingerRub      0.813     0.674     0.737       129
#  FingerSlider      0.746     0.866     0.801       149
#        NoHand      0.976     1.000     0.988       124
#      PalmHold      0.940     0.916     0.928       119
#      PalmTilt      0.942     0.890     0.915       127
#    PinchIndex      0.535     0.744     0.623       133
#    PinchPinky      0.667     0.421     0.516       133
#          Pull      0.632     0.821     0.714       117
#          Push      0.744     0.578     0.650       116
# RandomGesture      0.810     0.797     0.803       118
#   SlowSwipeRL      0.895     0.850     0.872       120
#
#      accuracy                          0.797      1623
#     macro avg      0.809     0.798     0.797      1623
#  weighted avg      0.806     0.797     0.795      1623

# %%
# Load TFLite model
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize

interpreter = tf.lite.Interpreter(model_path=r"\Code\model_training_grayscale_images\deployable_2cnn_model_int8.tflite")
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def predict_tflite_proba(sequence):
    # Quantization parameters for the input
    scale, zero_point = input_details[0]['quantization']
    
    # Quantize float32 input to int8
    input_tensor = (sequence / scale + zero_point).astype(np.int8)
    input_tensor = np.expand_dims(input_tensor, axis=0)  # Add batch dimension

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], input_tensor)
    interpreter.invoke()

    # Dequantize output (optional but useful for ROC/PR curves)
    output_data = interpreter.get_tensor(output_details[0]['index'])[0]
    out_scale, out_zero_point = output_details[0]['quantization']
    output_dequant = (output_data.astype(np.float32) - out_zero_point) * out_scale

    return output_dequant

# Gather predictions and scores
y_true, y_scores = [], []
for X_batch, y_batch in val_gen:
    for i in range(len(X_batch)):
        y_true.append(int(y_batch[i]))
        y_scores.append(predict_tflite_proba(X_batch[i]))

y_true = np.array(y_true)
y_scores = np.array(y_scores)
y_pred = np.argmax(y_scores, axis=1)

# Convert labels to one-hot for metrics
n_classes = len(label_map)
y_true_bin = label_binarize(y_true, classes=range(n_classes))

# ROC Curve
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curves 2 CNN-1D Convolution Int8")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# Precision-Recall Curve
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_scores[:, i])
    avg_precision = average_precision_score(y_true_bin[:, i], y_scores[:, i])
    plt.plot(recall, precision, label=f"Class {i} (AP = {avg_precision:.2f})")
plt.title("Precision-Recall Curves 2 CNN-1D Convolution Int8")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# Confidence Score Distribution
conf_scores = np.max(y_scores, axis=1)
plt.figure(figsize=(10, 6))
sns.histplot(conf_scores, bins=30, kde=True)
plt.title("Confidence Score Distribution 2 CNN-1D Convolution Int8")
plt.xlabel("Confidence")
plt.ylabel("Frequency")
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Making Data for Validation

# %%
def save_float32_csv_for_validation_one_file(generator, label_map, output_dir="csv_validation_data", samples_per_gesture=3):
    import os
    import numpy as np

    os.makedirs(output_dir, exist_ok=True)

    gesture_counts = {label: 0 for label in label_map.values()}
    all_inputs = []
    all_labels = []

    num_classes = len(label_map)

    for X_batch, y_batch in generator:
        for i in range(len(y_batch)):
            label = int(y_batch[i])
            if gesture_counts[label] >= samples_per_gesture:
                continue

            # Flatten input (already in [0, 1] float32)
            input_data = X_batch[i]
            flat_input = input_data.flatten()
            all_inputs.append(flat_input)

            # One-hot encode label
            one_hot = np.zeros(num_classes, dtype=int)
            one_hot[label] = 1
            all_labels.append(one_hot)

            gesture_counts[label] += 1

        if all(count >= samples_per_gesture for count in gesture_counts.values()):
            break

    # Save to CSV
    input_path = os.path.join(output_dir, "all_inputs.csv")
    label_path = os.path.join(output_dir, "all_labels.csv")

    np.savetxt(input_path, all_inputs, fmt='%.6f', delimiter=',')
    np.savetxt(label_path, all_labels, fmt='%d', delimiter=',')

    print(f"Saved {len(all_inputs)} samples to:")
    print(f"  → {input_path}")
    print(f"  → {label_path}")

# %%
save_float32_csv_for_validation_one_file(val_gen, label_map, output_dir="2_cnn_1dc_val_data_float32_ten", samples_per_gesture=10)
# Out:
# Saved 130 samples to:
#   → 2_cnn_1dc_val_data_float32_ten\all_inputs.csv
#   → 2_cnn_1dc_val_data_float32_ten\all_labels.csv
